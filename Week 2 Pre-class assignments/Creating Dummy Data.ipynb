# %% [markdown]
# **Student Name: Huynh Truong Tu**

# %% [markdown]
# Below are my assignment for creating dummy data

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **[Problem 1] Creating random numbers**

# %%
import numpy as np
__init__ = [1 , 0.8 , 0.8 , 1.0] #initial cov matrix
mean = (3,0)
cov = np.array(__init__).reshape(2,2)
list_rd = np.random.multivariate_normal(mean, cov, 500)
list_rd.reshape(500,2)
np.random.seed(0)

# %%
print("Number of data in the array is:",len(list_rd))
# Out:
# Number of data in the array is: 500

# %% [markdown]
# **[Problem 2] Visualization by scatter plot**

# %%
import matplotlib.pyplot as plt
plt.title("scatter")
plt.xlabel("x1")
plt.ylabel("x2")
plt.scatter(list_rd[:,0],list_rd[:,1])
plt.show()

# %% [markdown]
# **[Problem 3] Visualization by histogram**

# %%
import matplotlib.pyplot as plt
plt.title("histogram of x1")
plt.xlabel("x1")
plt.ylabel("frequency")
plt.hist(list_rd[:,1],rwidth=1)
plt.xlim(-3,6)
plt.show()
plt.title("histogram of x2")
plt.xlabel("x2")
plt.ylabel("frequency")
plt.hist(list_rd[:,0])
plt.xlim(-3,6)
plt.show()

# %% [markdown]
# **[Problem 4] Addition of data**

# %%
import numpy as np
__init__ = [1 , 0.8 , 0.8 , 1.0] #initial cov matrix
mean = (0,3)
cov = np.array(__init__).reshape(2,2)
addition= np.random.multivariate_normal(mean, cov, 500)
addition.reshape(500,2)
np.random.seed(1)

# %%
print("Number of data in the array is:",len(addition))
# Out:
# Number of data in the array is: 500

# %%
import matplotlib.pyplot as plt
plt.title("scatter")
plt.xlabel("x1")
plt.ylabel("x2")
plt.scatter(addition[:,0],addition[:,1],label="0")
plt.scatter(list_rd[:,0],list_rd[:,1],label="1")
plt.legend(loc = 'best', borderaxespad=0.5)
plt.show()

# %% [markdown]
# **[Problem 5] Data combination**

# %%
combined_data = np.concatenate((list_rd,addition))
print(len(combined_data))
# Out:
# 1000

# %% [markdown]
# **[Problem 6] Labeling**

# %%
label_zero = np.zeros((500,3))
label_zero[:,:-1] = list_rd
label_one = np.ones((500,3))
label_one[:,:-1] = addition
combined_label = np.concatenate((label_zero,label_one))
print(combined_label)
# Out:
# [[ 1.65246505 -1.73444368  0.        ]
#  [ 3.84037019  0.16176525  0.        ]
#  [ 2.90681268 -1.5488082   0.        ]
#  ...
#  [-0.40484501  2.85627742  1.        ]
#  [ 0.1584315   3.21800394  1.        ]
#  [ 1.20196495  3.97547372  1.        ]]

# %% [markdown]
# ========================================================================================================================

# %% [markdown]
# This is the end of my assignment, thank you for reading!
